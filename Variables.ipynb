# %% [markdown]
# ### Variables:

# %% [markdown]
# - variable term vary
# - you want to save some values at some place, that place is called variables
# - variables and constant

# %%
number = 100 #100 value is stored in variable called number
number       #so here number is a  variable
# Out:
# 100

# %%
number = 200
number
# Out:
# 200

# %% [markdown]
# #### Rules to define variables

# %%
#Upper case
NUMBER=300
NUMBER
# Out:
# 300

# %%
#Lower Case
number = 400
number
# Out:
# 400

# %%
#Combination of upper case and lower case
NUMber=500
NUMber
# Out:
# 500

# %%
#Combination of Letters and numbers, numbers as suffix
number123=600
number123
# Out:
# 600

# %%
#Combiantion of Letters and numbers, numbers as prefix
123number=700
123number
# Out:
#   File "C:\Users\Venky\AppData\Local\Temp\ipykernel_14572\1126546289.py", line 2
#     123number=700
#        ^
# SyntaxError: invalid syntax

# %%
#special character
number%=800
number%
# Out:
#   File "C:\Users\Venky\AppData\Local\Temp\ipykernel_14572\819122675.py", line 3
#     number%
#            ^
# SyntaxError: invalid syntax

# %%
#underscore
number_=900
number_
# Out:
# 900

# %%
#keywords
if=500
if
# Out:
#   File "C:\Users\Venky\AppData\Local\Temp\ipykernel_14572\99386868.py", line 2
#     if=500
#       ^
# SyntaxError: invalid syntax

# %%
sum =700
sum
# Out:
# 700

# %% [markdown]
# **Note**:
#     Sum is a math operation it will works
#
#       but do not use as variable

# %%
#spaces will not allowed
number one =9
number one
# Out:
#   File "C:\Users\Venky\AppData\Local\Temp\ipykernel_14572\1468944783.py", line 1
#     number one =9
#            ^
# SyntaxError: invalid syntax

# %%
_=20
_
# Out:
# 20

# %% [markdown]
# ####### Basics #######
# 1) Basic syntax
# 2) variables
# 3) Python packages information
# 4) Basic python code
# 5) conditional statements
# 6) Functions
# 7) Loop
#
# ####### Level-2 #######
# 1) Strings
# 2) List
# 3) Dictionary
# 4) Tuples
# 5) Sets
# 6) File handling sessions
#
#
# EDA : Python
#
# ####### Level-3 #######
# 1) OOPS concept in python
# 2) How to create your own packages
# 3) FLASK APPS
