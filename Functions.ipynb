# %%
import math
pi=math.pi

# %%
pi
# Out:
# 3.141592653589793

# %%
import math
r=eval(input("Enter radius "))
Area= pi*r**2
Area
# Out:
# Enter radius 5
# 78.53981633974483

# %%
import math
def area_of_circle(r):
    pi=math.pi
    area=pi*r**2
    print("Area of Circle",area)

# %%
area_of_circle(4)
# Out:
# Area of Circle 50.26548245743669

# %%
import math
def area_of_circle(r):
    pi=math.pi
    area=pi*r**2
    print("Area of Circle",area)
area_of_circle(eval(input("Enter Radius: ")))
# Out:
# Enter Radius: 5
# Area of Circle 78.53981633974483

# %%
import math
def area_of_circle(r):
    pi=math.pi
    area=pi*r**2
    print("Area of Circle",area)

# %%
area_of_circle(math.pi)
# Out:
# Area of Circle 31.006276680299816

# %%
def sum_avg(n1,n2,n3):
    summ=n1+n2+n3
    avg=summ/3
    print("Sum: ",summ)
    print("Avg: ",avg)
    
sum_avg(40,20,10)
# Out:
# Sum:  70
# Avg:  23.333333333333332

# %%
def sum_avg(n1,n2,n3):
    summ=n1+n2+n3
    avg=summ/3
    print("Sum: ",summ)
    print("Avg: ",avg)
    return(summ,avg)
    
addition,average=sum_avg(40,20,10)
print("Addition: ",addition,"Average: ",average)
# Out:
# Sum:  70
# Avg:  23.333333333333332
# Addition:  70 Average:  23.333333333333332

# %%
def greater(a1,b1,c1):
    if a1>b1 and a1>c1:
        print("a1 is greater")
    elif b1>c1:
        print("b1 is greater")
    else:
        print("c1 is greater")
        
greater(45,50,60)
# Out:
# c1 is greater

# %%
def greater():
    a1=eval(input("Enter a1 number: "))
    b1=eval(input("Enter b1 number: "))
    c1=eval(input("Enter c1 number: "))
    if a1>b1 and a1>c1:
        print("a1 is greater")
    elif b1>c1:
        print("b1 is greater")
    else:
        print("c1 is greater")
        
greater()
# Out:
# Enter a1 number: 80
# Enter b1 number: 60
# Enter c1 number: 70
# a1 is greater

# %%
def greater():
    a1=eval(input("Enter a1 number: "))
    b1=eval(input("Enter b1 number: "))
    c1=eval(input("Enter c1 number: "))
    if a1>b1 and a1>c1:
        print("{} is greater".format(a1))
    elif b1>c1:
        print("{} is greater".format(b1))
    else:
        print("{} is greater".format(c1))
        
greater()
# Out:
# Enter a1 number: 45
# Enter b1 number: 80
# Enter c1 number: 60
# 80 is greater

# %%
def greater():
    a1=eval(input("Enter a1 number: "))
    b1=eval(input("Enter b1 number: "))
    c1=eval(input("Enter c1 number: "))
    if a1>b1 and a1>c1:
        print("a1 is greater,i.e {}".format(a1))
    elif b1>c1:
        print("b1 is greater,i.e {}".format(b1))
    else:
        print("c1 is greater,i.e {}".format(c1))
        
greater()
# Out:
# Enter a1 number: 70
# Enter b1 number: 50
# Enter c1 number: 10
# a1 is greater,i.e 70

# %%
def greater():
    a1=eval(input("Enter a1 number: "))
    a2=eval(input("Enter a2 number: "))
    a3=eval(input("Enter a3 number: "))
    if a2<a1>a3:
        print("a1 is greater, i.e {}".format(a1))
        a=a1
    elif a2>a3:
        print("a2 is greater, i.e {}".format(a2))
        a=a2
    else:
        print("a3 is greater, i.e {}".format(a3))
        a=a3
    return(a)
a=greater()
print(a)
# Out:
# Enter a1 number: 7
# Enter a2 number: 5
# Enter a3 number: 2
# a1 is greater, i.e 7
# 7

# %%
def add(a,b):
    return(a+b)

val=add(20,10)
print(val)
# Out:
# 30

# %%
def sub(c,d):
    return(c-d)

val=sub(40,30)
print(val)
# Out:
# 10

# %%
def mul(e,f):
    return(e*f)

val=mul(12,3)
print(val)
# Out:
# 36

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a//b)

c,d,e,f=aggregation(10,20)
print(c,d,e,f)
# Out:
# 30 -10 200 0

# %%
val=aggregation(10,20)
print(val)
# Out:
# (30, -10, 200, 0)

# %%
def add(a,b):return(a+b)
val=add(5,6) 
print(val)
# Out:
# 11

# %% [markdown]
# # Local Variables

# %%
def addition():
    n1=20
    n2=30
    add=n1+n2
    print("The addition of {} and {} is {}".format(n1,n2,add))

# %%
addition()
# Out:
# The addition of 20 and 30 is 50

# %% [markdown]
# # Global Variables

# %%
n1=30
n2=40
def addition():
    add=n1+n2
    print("The addition of {} and {} is {}".format(n1,n2,add))
    
addition()
# Out:
# The addition of 30 and 40 is 70

# %%
a1=eval(input("Enter a1 number: "))
a2=eval(input("Enter a2 number: "))
a3=eval(input("Enter a3 number: "))
if a2<a1>a3:
    print("a1 is greater, i.e {}".format(a1))
    a=a1
elif a2>a3:
    print("a2 is greater, i.e {}".format(a2))
    a=a2
else:
    print("a3 is greater, i.e {}".format(a3))
    a=a3
print(a)
# Out:
# Enter a1 number: 5
# Enter a2 number: 4
# Enter a3 number: 2
# a1 is greater, i.e 5
# 5

# %%
def val():
    global num1,num2
    num1=10
    num2=20
    print(num1+num2)
val()
print(num1)
# Out:
# 30
# 10

# %%
n_=10
def updated():
    global n_
    n_=50
    n_=n_+ 20
    print(n_)
updated()
print(n_)
# Out:
# 70
# 70

# %% [markdown]
# # Function in Function

# %%
def greet():
    print("Hello")

def name():
    print("Python")
    
greet()
name()
# Out:
# Hello
# Python

# %%
def greet():
    print("Hello")

def name():
    print("Python")
    greet()
    
name()
# Out:
# Python
# Hello

# %%
def greet():
    print("Hello")
    name()

def name():
    print("Python")
    
greet()
# Out:
# Hello
# Python

# %%
def greet():
    print("Hello")
    name()

def name():
    print("Python")
    greet()
    
greet()    
name()
