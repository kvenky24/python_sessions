# %%
Basic_salary=eval(input("Enter the basic salary: "))
DA=eval(input("Enter the DA amount: "))
HRA=eval(input("Enter the HRA amount: "))
Total_pay= Basic_salary+DA+HRA
print("Total_Salary=" ,Total_pay)
# Out:
# Enter the basic salary: 50000
# Enter the DA amount: 500
# Enter the HRA amount: 10000
# Total_Salary= 60500

# %%
Basic_salary=eval(input("Enter the basic salary: "))
Tax_percentage=eval(input("Enter the tax %: "))
Tax_need_to_pay= Basic_salary*10/100
print("Tax need to pay=" ,Tax_need_to_pay)
# Out:
# Enter the basic salary: 45000
# Enter the tax %: 10
# Tax need to pay= 4500.0

# %%
number=eval(input("Enter a number "))
square=number*number
print("the sqaure of number is: ",square)
# Out:
# Enter a number 55
# the sqaure of number is:  3025

# %%
import random
number1=random.randint(1,50)
square=number1*number1
print("the sqaure of given number is: ",square)
# Out:
# the sqaure of given number is:  100

# %%
Distance=eval(input("Enter the Distance : "))
Rate_per_distance=eval(input("Enter the rate per distance: "))
Total_charge= Distance*Rate_per_distance
print("for {}km charge is {}rs ".format(Distance,Total_charge))
# Out:
# Enter the Distance : 45
# Enter the rate per distance: 12
# for 45km charge is 540rs

# %% [markdown]
# #### Exception Handling

# %%
try:
    num1:eval(input("Enter number-1:"))
    num2:eval(input("Enter number-2:"))
    num3:eval(input("Enter number-3:"))
    average=(num1+num2+num3)/0
    print('The Average of {},{},|{} is {}'.format(num1,num2,num3,average))
    
except Exception as e:
    print(e)
# Out:
# Enter number-1:5
# Enter number-2:5
# Enter number-3:2
# name 'num1' is not defined

# %%
distance = eval(input('Enter distance in km'))
if distance>=10:
    print('The charge is 100rs')
    
elif distance>=7:
    print('The charge is 70rs')
    
elif distance>=4:
    print('The charge is 40rs')
    
else:
    print('The charge is 30rs')
# Out:
# Enter distance in km5
# The charge is 40rs

# %%
salary=(eval(input('Enter the salary:')))
if salary>=1000000:
    tax_per=eval(input('Enter the tax percentage: '))
    print('Amount of tax paid:',(salary*tax_per)/100)
    
elif salary>=700000:
    tax_per=eval(input('Enter the tax percentage: '))
    print('Amount of tax paid:',(salary*tax_per)/100)
    
elif salary>=500000:
    tax_per=eval(input('Enter the tax percentage: '))
    print('Amount of tax paid:',(salary*tax_per)/100)
    
else:
    print('No tax is required')
# Out:
# Enter the salary:40000
# No tax is required

# %%
number =eval(input('Enter a number: '))
if number>0:
    if number==0:
        print("It's a Zero number")
    else:
        print("It's a positive number")
              
else:
    print("It's a negative number")
# Out:
# Enter a number: -8
# It's a negative number

# %%
n =(input())
# Out:
# 5

# %%
m = eval(input())
# Out:
# 2

# %%
a=10
b=20
add=a+b
print(add)
# Out:
# 30

# %%
def addition():
    a=800
    b=20
    add=a+b
    print(add)

# %%
addition()
# Out:
# 820

# %%
def game():
    print("Hello")
    print("Namasthe")

# %%
game()
# Out:
# Hello
# Namasthe

# %%
def avg():
    n1=eval(input("Enter number 1:"))
    n2=eval(input("Enter number 2:"))
    n3=eval(input("Enter number 3:"))
    avg=(n1+n2+n3)/3
    print("The average of {},{} and {} is {}".format(n1,n2,n3,avg))

# %%
avg()
# Out:
# Enter number 1:52
# Enter number 2:45
# Enter number 3:78
# The average of 52,45 and 78 is 58.333333333333336

# %%
def avg():
    try:
        n1=eval(input("Enter number 1:"))
        n2=eval(input("Enter number 2:"))
        n3=eval(input("Enter number 3:"))
        avg=(n1+n2+n33)/3
        print("The average of {},{} and {} is {}".format(n1,n2,n3,avg))
    except Exception as e:
        print(e)

# %%
avg()
# Out:
# Enter number 1:45
# Enter number 2:42
# Enter number 3:12
# name 'n33' is not defined

# %%
import random
number = random.randint(1,50)
if number%2 == 0:
    print("{} is an Even Number".format(number))
else:
    print("{} is an Odd Number".format(number))
# Out:
# 41 is an Odd Number

# %%
import random
def even_odd():
    try:
        number = random.randint(1,50)
        if number%2 == 0:
            print("{} is an Even Number".format(number))
        else:
            print("{} is an Odd Number".format(number))
    except Exception as e:
        print(e)

# %%
even_odd()
# Out:
# 5 is an Odd Number

# %%
def add():
    print('addition function starts')
    a=12
    b=20
    print('add:',a+b)
    print('addition is done')
    
def mul():
    print('multiplication function starts')
    a=3
    b=4
    print('mul:',a*b)
    print('multiplication is done')
    

def sub():
    print('subtraction function starts')
    a=50
    b=24
    print('sub:',a-b)
    print('subtarction is done')

mul()
add()
sub()
# Out:
# multiplication function starts
# mul: 12
# multiplication is done
# addition function starts
# add: 32
# addition is done
# subtraction function starts
# sub: 26
# subtarction is done

# %%
def add(n1,n2):
    add=n1+n2
    print(add)

# %%
add(12,23)
# Out:
# 35

# %%
add(85555,7845)
# Out:
# 93400

# %%
print(5,end='')
print(4)
# Out:
# 54

# %%
number=eval(input("Enter a number:"))
print("The square of the {} is {}".format(number,number*number))
# Out:
# Enter a number:5
# The square of the 5 is 25

# %%
def square(number):
    print("The square of the {} is {}".format(number,number*number))

square(4)
# Out:
# The square of the 4 is 16

# %%
import random
def num_check(a):
    num=random.randint(1,20)
    if num == a:
        print("You Won")
    else:
        print("Lost, because random number is",format(num))

# %%
num_check(55)
# Out:
# Lost, because random number is 18

# %%
num_check(9)
# Out:
# Lost, because random number is 11

# %%
num_check(15)
# Out:
# Lost, because random number is 11

# %%
import random
def venky():
    random_num=random.randint(1,20)
    num=eval(input("Enter a number:"))
    if random_num == num:
        print("You Won")
    else:
        print("Lost, because random number is",format(random_num))

# %%
venky()
# Out:
# Enter a number:15
# Lost, because random number is 12

# %%
venky()
# Out:
# Enter a number:20
# Lost, because random number is 1

# %%
venky()
# Out:
# Enter a number:4
# Lost, because random number is 2

# %%
import random
random.randint(1,10)
# Out:
# 1

# %%
from random import randint
randint(1,10)
# Out:
# 10

# %%
import random
def venkatesh():
    bujji=random.randint(1,25)
    venky=eval(input("Enter a number:"))
    if bujji==venky:
        print("You won")
    else:
        print("You Lost, because bujji is ",format(bujji))

# %%
venkatesh()
# Out:
# Enter a number:25
# You Lost, because bujji is  10

# %%
import random
def compare(user_num,rand_num):
    try:
        if rand_num==user_num:
            print("You won")
        else:
            print("You are not a winner, becuase random number is ",format(rand_num))
    except Exception as e:
        print(e)

user_num=eval(input("Enter user number: "))
rand_num=random.randint(1,25)
compare(user_num,rand_num)
# Out:
# Enter user number: 20
# You are not a winner, becuase random number is  3

# %%
def avg(num1,num2,num3):
    add=num1+num2+num3
    avg=add/3
    print("The avg : ",format(avg))
avg(25,41,20)
# Out:
# The avg :  28.666666666666668

# %%
avg(45,25,100)
# Out:
# The avg :  56.666666666666664

# %%
def avg(num1,num2,num3=50):
    add=num1+num2+num3
    avg=add/3
    print("The avg : ",format(avg))
avg(25,41)
# Out:
# The avg :  38.666666666666664

# %%
import random
random.randint(1,50)
# Out:
# 10
